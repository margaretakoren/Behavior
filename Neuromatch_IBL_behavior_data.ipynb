# %% [markdown]
# <a href="https://colab.research.google.com/github/margaretakoren/Behavior/blob/main/Neuromatch_IBL_behavior_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation and configuration of IBL packages

# %%
# !pip install --quiet ONE-api
# !pip install --quiet ibllib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.2/115.2 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.9/320.9 kB 25.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.6/180.6 kB 17.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.3/237.3 kB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 63.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 31.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 9.1 MB/s eta 0:00:00
#   Building wheel for nptdms (pyproject.toml) ... done

# %%
from one.api import ONE
ONE.setup(base_url='https://openalyx.internationalbrainlab.org', silent=True)
one = ONE(password='international')
# Out:
# Connected to https://openalyx.internationalbrainlab.org as user "intbrainlab"
# Downloading: /root/Downloads/ONE/openalyx.internationalbrainlab.org/tmpn8c3cjdi/cache.zip Bytes: 6254178
# 100%|██████████| 5.964448928833008/5.964448928833008 [00:00<00:00, 10.82it/s]

# %% [markdown]
# # Finding subjects with training data

# %%
import numpy as np

# Find all aggregate training datasets from paper Brujins et al
datasets = one.alyx.rest('datasets', 'list', tag='2023_Q4_Bruijns_et_al')

# Find the subject name from the info stored in the relative path
subjects = np.unique([d['file_records'][0]['relative_path'].split('/')[-2] for d in datasets])

# %% [markdown]
# # Loading trials data for a single subject

# %%
# Load in the subjectTrials table for the first subject
subject = subjects[0]
subject_trials = one.load_aggregate('subjects', subject, '_ibl_subjectTrials.table')


# Add in lab, task_protocol, subject name information from the ONE cache
if 'task_protocol' in subject_trials:
    subject_trials = subject_trials.drop('task_protocol', axis=1)
subject_trials = subject_trials.set_index('session').join(one._cache.sessions.drop('date', axis=1))
# Out:
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL045/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.47M/5.47M [00:00<00:00, 6.96MB/s]

# %% [markdown]
# The `subject_trials` table contains all the trials data for each training session collected in the subject. See [here](https://docs.google.com/document/d/1OqIqqakPakHXRAwceYLwFY9gOrm8_P62XIfCTnHwstg/edit#heading=h.ls81qq9ihg4x) for more information about this dataset.
#
# We can find the number of sessions collected, or the number of times the subject was run under a specific task protocol

# %%
# Find the number of sessions for this subject
n_sessions = subject_trials.index.unique().size
print(f'Subject {subject} has {n_sessions} sessions')

# Find the number of times a task protocol was run
n_protocols = subject_trials[~subject_trials.index.duplicated()].task_protocol.value_counts()
print(n_protocols)
# Out:
# Subject CSHL045 has 76 sessions
# task_protocol
# _iblrig_tasks_biasedChoiceWorld6.3.1      17
# _iblrig_tasks_trainingChoiceWorld6.1.3    14
# _iblrig_tasks_trainingChoiceWorld6.2.5    12
# _iblrig_tasks_trainingChoiceWorld6.3.1    11
# _iblrig_tasks_biasedChoiceWorld6.2.5       6
# _iblrig_tasks_ephysChoiceWorld6.2.5        3
# _iblrig_tasks_trainingChoiceWorld6.2.4     3
# _iblrig_tasks_trainingChoiceWorld6.0.6     3
# _iblrig_tasks_trainingChoiceWorld6.2.1     2
# _iblrig_tasks_ephysChoiceWorld6.4.0        2
# _iblrig_tasks_trainingChoiceWorld6.2.0     1
# _iblrig_tasks_trainingChoiceWorld6.1.1     1
# _iblrig_tasks_trainingChoiceWorld6.1.2     1
# Name: count, dtype: int64

# %% [markdown]
# We can get the trials data for an individual session of choice, here a the first session using the biasedChoiceWorld protocol

# %%
# Get the trials data for a single session
# Find a session run under biasedChoiceWorld
sess = subject_trials[subject_trials['task_protocol'].str.contains('biasedChoiceWorld')].index.unique()[0]
trials = subject_trials[subject_trials.index == sess]

# %% [markdown]
# Using this data we can plot the psychometric curve and compute some performance metrics, for example the number of trials in the session or the performance of the mouse on easy trials (50% and 100% contrast)

# %%
from brainbox.behavior.training import plot_psychometric, compute_n_trials, compute_performance_easy, compute_performance

plot_psychometric(trials)
n_trials = compute_n_trials(trials)
perf_easy = compute_performance_easy(trials)
print(f'Number of trials for session {sess}: {n_trials}')
print(f'Performance easy for session {sess}: {perf_easy}')
# Out:
# Number of trials for session 1a559aac-f6dd-47c8-bccb-53b4ae5af509: 1152
# Performance easy for session 1a559aac-f6dd-47c8-bccb-53b4ae5af509: 0.9764705882352941

# %% [markdown]
# ## Combining training criteria

# %% [markdown]
# Another [dataset](https://docs.google.com/document/d/1OqIqqakPakHXRAwceYLwFY9gOrm8_P62XIfCTnHwstg/edit#heading=h.18vu2zskyq0r) is available that contains information about the session at which the subject reached certain training criteria in the IBL training pipeline. More information can be found about the training pipeline in the study [A standardized and reproducible method to measure decision-making in mice](https://doi.org/10.1101/2020.01.17.909838).
#
# We can download this dataset in the following way

# %%
subject_training = one.load_aggregate('subjects', subject, '_ibl_subjectTraining.table')
# Out:
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL045/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 18.7kB/s]

# %% [markdown]
# We can combine this with our subject trials table to see how the subject progressed

# %%
subject_trials = (subject_trials
          .join(subject_training.set_index('session'))
          .sort_values(by=['session_start_time', 'intervals_0']))
subject_trials['training_status'] = subject_trials.training_status.fillna(method='ffill')

# %% [markdown]
# Our subject trials table now has a new column that indicates the training criteria of the mouse at each session. We can use this information to make a plot of how the performance of the mouse improved across training days.
#
# We will need to compute the performance per session and add this column to our dataframe and also add in a column for training day.

# %%
sessions = subject_trials.index.unique()
for n_sess, sess in enumerate(sessions):
  trials = subject_trials[subject_trials.index == sess]
  perf_easy = compute_performance_easy(trials)
  subject_trials.loc[subject_trials.index == sess, 'performance_easy'] = perf_easy
  subject_trials.loc[subject_trials.index == sess, 'training_day'] = n_sess

# %% [markdown]
# Note since we already ordered by session_start_time above our table was already sorted. Here we have simply assigned each training session to a training day but there are some cases where multiple training sessions were run on the same day so this may be something you want to account for in your analysis.

# %%
import matplotlib.pyplot as plt
from ibllib.pipes.training_status import TRAINING_STATUS
fig, ax = plt.subplots(1, 1)
ax.plot(subject_trials['training_day'], subject_trials['performance_easy'] * 100)
ax.set_xlabel("Training day")
ax.set_ylabel("Performance Easy (%)")
status = subject_trials.drop_duplicates(subset='training_status', keep='first')
for _, st in status.iterrows():
    if st['training_status'] in ['untrainable', 'unbiasable']:
        continue
    if TRAINING_STATUS[st['training_status']][0] <= 0:
        continue
    ax.axvline(st['training_day'], linewidth=2,
               color=np.array(TRAINING_STATUS[st['training_status']][1]) / 255, label=st['training_status'])
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
                   fancybox=True, shadow=True, ncol=5)

# %% [markdown]
# # Combining data across multiple subjects

# %% [markdown]
# We can loop over all the subjects available to get a large dataframe that contains the data for all the subjects. Here is an example of how this can be done

# %%
import pandas as pd

all_trials = []

# Download two tables, subject trials table and subject training table and combine
for i, subject in enumerate(subjects):
  if np.mod(i, 50) == 0:
    print(f'{i}/{len(subjects)}')

  # Load trials table for subject
  subject_trials = one.load_aggregate('subjects', subject, '_ibl_subjectTrials.table')

  # Load training status for subject
  subject_training = one.load_aggregate('subjects', subject, '_ibl_subjectTraining.table')

  # Combine the two tables
  subject_trials = (subject_trials
            .set_index('session')
            .join(subject_training.set_index('session'))
            .sort_values(by=['session_start_time', 'intervals_0']))
  subject_trials['training_status'] = subject_trials.training_status.fillna(method='ffill')

  # Join sessions table for number, task_protocol, etc.
  if 'task_protocol' in subject_trials:
      subject_trials = subject_trials.drop('task_protocol', axis=1)
  subject_trials = subject_trials.join(one._cache.sessions.drop('date', axis=1))

  # Sort the trials by session start time and trial number
  subject_trials = subject_trials.sort_values(by=['session_start_time', 'intervals_0'])


  # add in extra columns for performance easy and training day
  sessions = subject_trials.index.unique()
  for n_sess, sess in enumerate(sessions):
    trials = subject_trials[subject_trials.index == sess]
    perf_easy = compute_performance_easy(trials)
    subject_trials.loc[subject_trials.index == sess, 'performance_easy'] = perf_easy
    subject_trials.loc[subject_trials.index == sess, 'training_day'] = n_sess


  all_trials.append(subject_trials)

all_trials = pd.concat(all_trials)
# Out:
# 0/156
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL047/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.61M/3.61M [00:00<00:00, 4.95MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL047/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.21k/3.21k [00:00<00:00, 17.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL049/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.81M/2.81M [00:00<00:00, 3.98MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL049/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL051/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.36M/3.36M [00:00<00:00, 4.42MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL051/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL052/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.37M/4.37M [00:00<00:00, 5.58MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL052/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.27k/3.27k [00:00<00:00, 18.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL053/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.33M/3.33M [00:00<00:00, 4.57MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL053/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 15.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL054/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.51M/3.51M [00:00<00:00, 5.24MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL054/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL055/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.85M/4.85M [00:02<00:00, 1.78MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL055/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 17.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL058/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.50M/4.50M [00:00<00:00, 6.26MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL058/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL059/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.40M/2.40M [00:00<00:00, 3.55MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL059/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 16.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL060/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.29M/3.29M [00:00<00:00, 4.41MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL060/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL_007/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.82M/2.82M [00:00<00:00, 3.99MB/s]
# /usr/local/lib/python3.10/dist-packages/one/api.py:1829: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   records.loc[i, 'exists_aws'] = any(
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL_007/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 14.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL_014/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.96M/4.96M [00:00<00:00, 5.77MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL_014/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL_015/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.00M/5.00M [00:00<00:00, 6.64MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab/CSHL_015/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL_020/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.76M/1.76M [00:00<00:00, 2.98MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab/CSHL_020/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.08k/3.08k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_001/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.94M/2.94M [00:00<00:00, 3.29MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_001/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/zadorlab/CSH_ZAD_011/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.64M/2.64M [00:00<00:00, 3.52MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_011/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_017/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.88M/2.88M [00:00<00:00, 3.98MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_017/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_019/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.55M/5.55M [00:00<00:00, 7.21MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_019/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.31k/3.31k [00:00<00:00, 19.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_022/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.52M/2.52M [00:00<00:00, 3.45MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_022/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/zadorlab/CSH_ZAD_024/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.79M/2.79M [00:00<00:00, 3.47MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_024/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_025/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.73M/1.73M [00:00<00:00, 2.96MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_025/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/zadorlab/CSH_ZAD_026/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.17M/2.17M [00:00<00:00, 3.37MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_026/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_029/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.64M/3.64M [00:00<00:00, 4.90MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/zadorlab/CSH_ZAD_029/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_008/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.71M/2.71M [00:00<00:00, 4.00MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_008/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/danlab/DY_009/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.30M/3.30M [00:00<00:00, 4.51MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_009/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/danlab/DY_010/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.61M/2.61M [00:00<00:00, 3.57MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/danlab/DY_010/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/danlab/DY_011/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.55M/2.55M [00:00<00:00, 2.80MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_011/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_013/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.30M/1.30M [00:00<00:00, 2.21MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/danlab/DY_013/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_014/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.24M/2.24M [00:00<00:00, 3.24MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_014/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_016/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.34M/1.34M [00:00<00:00, 2.29MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_016/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_018/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.61M/2.61M [00:00<00:00, 3.78MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_018/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_020/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.43M/2.43M [00:00<00:00, 3.63MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/danlab/DY_020/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS014/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.82M/2.82M [00:00<00:00, 4.38MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS014/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 7.35kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS015/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.99M/1.99M [00:00<00:00, 3.30MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS015/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS016/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.89M/2.89M [00:00<00:00, 4.24MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS016/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS017/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.89M/1.89M [00:00<00:00, 3.31MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS017/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 18.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS019/_ibl_subjectTrials.table.pqt: 100%|██████████| 6.03M/6.03M [00:00<00:00, 7.15MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS019/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 19.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS021/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.03M/4.03M [00:00<00:00, 5.34MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS021/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 17.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS022/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.28M/2.28M [00:00<00:00, 3.32MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS022/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 18.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS023/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.78M/1.78M [00:00<00:00, 2.79MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS023/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS042/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.83M/1.83M [00:00<00:00, 3.12MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS042/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS043/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.53M/3.53M [00:00<00:00, 4.22MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS043/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS044/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.05M/4.05M [00:00<00:00, 5.49MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS044/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS045/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.43M/2.43M [00:00<00:00, 3.60MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS045/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 17.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS046/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.75M/2.75M [00:00<00:00, 3.97MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS046/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS051/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.48M/2.48M [00:01<00:00, 1.60MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS051/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS052/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.90M/2.90M [00:00<00:00, 3.86MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS052/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS055/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.64M/2.64M [00:00<00:00, 3.49MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS055/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 16.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS084/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.94M/1.94M [00:00<00:00, 2.88MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS084/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.9kB/s]
# 50/156
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS086/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.61M/3.61M [00:01<00:00, 2.78MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS086/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 12.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS091/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.88M/3.88M [00:00<00:00, 5.20MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS091/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS094/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.30M/2.30M [00:00<00:00, 3.46MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS094/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/cortexlab/KS096/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.94M/1.94M [00:00<00:00, 3.28MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/cortexlab/KS096/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_05/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.32M/3.32M [00:00<00:00, 4.97MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_05/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_06/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.09M/4.09M [00:00<00:00, 4.91MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_06/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 19.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_07/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.06M/4.06M [00:00<00:00, 5.06MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_07/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.24k/3.24k [00:00<00:00, 17.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_08/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.01M/4.01M [00:00<00:00, 4.97MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_08/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_09/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.50M/3.50M [00:00<00:00, 5.17MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/MFD_09/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 14.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/steinmetzlab/NR_0017/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.79M/3.79M [00:00<00:00, 5.18MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0017/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0019/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.98M/3.98M [00:00<00:00, 5.24MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0019/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 15.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/steinmetzlab/NR_0020/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.88M/4.88M [00:00<00:00, 6.81MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0020/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0021/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.62M/2.62M [00:00<00:00, 3.98MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0021/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0024/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.65M/5.65M [00:00<00:00, 7.34MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/steinmetzlab/NR_0024/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/steinmetzlab/NR_0027/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.53M/2.53M [00:00<00:00, 3.87MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0027/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0028/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.59M/2.59M [00:00<00:00, 3.74MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0028/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 15.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0029/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.83M/3.83M [00:00<00:00, 5.69MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0029/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.31k/3.31k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0031/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.38M/1.38M [00:00<00:00, 2.30MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/steinmetzlab/NR_0031/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-06/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.83M/3.83M [00:00<00:00, 5.47MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-06/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-11/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.19M/2.19M [00:00<00:00, 2.99MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-11/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.15k/3.15k [00:00<00:00, 17.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-12/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.26M/1.26M [00:00<00:00, 2.12MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-12/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/angelakilab/NYU-21/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.34M/4.34M [00:00<00:00, 6.08MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-21/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 19.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-27/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.20M/3.20M [00:00<00:00, 4.38MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-27/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-30/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.65M/3.65M [00:00<00:00, 4.58MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-30/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.31k/3.31k [00:00<00:00, 18.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-37/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.30M/2.30M [00:00<00:00, 3.33MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/angelakilab/NYU-37/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 18.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/angelakilab/NYU-39/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.66M/2.66M [00:01<00:00, 1.81MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-39/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-40/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.07M/2.07M [00:00<00:00, 3.09MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-40/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-45/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.51M/3.51M [00:00<00:00, 4.60MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/angelakilab/NYU-45/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-46/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.15M/2.15M [00:00<00:00, 3.32MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/angelakilab/NYU-46/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-47/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.70M/2.70M [00:00<00:00, 3.72MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/angelakilab/NYU-47/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-48/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.84M/2.84M [00:00<00:00, 4.13MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-48/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-65/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.24M/2.24M [00:00<00:00, 3.23MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/angelakilab/NYU-65/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 13.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hausserlab/PL015/_ibl_subjectTrials.table.pqt: 100%|██████████| 11.6M/11.6M [00:01<00:00, 10.8MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL015/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL016/_ibl_subjectTrials.table.pqt: 100%|██████████| 6.79M/6.79M [00:00<00:00, 7.27MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL016/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hausserlab/PL017/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.83M/4.83M [00:03<00:00, 1.53MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL017/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL024/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.01M/3.01M [00:00<00:00, 3.97MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL024/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 7.39kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL030/_ibl_subjectTrials.table.pqt: 100%|██████████| 11.0M/11.0M [00:00<00:00, 12.3MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hausserlab/PL030/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL031/_ibl_subjectTrials.table.pqt: 100%|██████████| 11.4M/11.4M [00:00<00:00, 12.4MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL031/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL033/_ibl_subjectTrials.table.pqt: 100%|██████████| 10.9M/10.9M [00:00<00:00, 12.1MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL033/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL034/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.26M/2.26M [00:00<00:00, 3.21MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL034/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.07k/3.07k [00:00<00:00, 15.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL035/_ibl_subjectTrials.table.pqt: 100%|██████████| 8.07M/8.07M [00:00<00:00, 9.43MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL035/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 19.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL037/_ibl_subjectTrials.table.pqt: 100%|██████████| 9.84M/9.84M [00:00<00:00, 11.5MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL037/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 14.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hausserlab/PL050/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.82M/2.82M [00:00<00:00, 3.68MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hausserlab/PL050/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_021/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.01M/4.01M [00:00<00:00, 5.31MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_021/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 17.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_022/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.56M/1.56M [00:00<00:00, 2.43MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_022/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.07k/3.07k [00:00<00:00, 18.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_023/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.97M/3.97M [00:00<00:00, 5.00MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_023/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 6.54kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_038/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.66M/3.66M [00:00<00:00, 5.29MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_038/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 19.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_039/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.21M/4.21M [00:00<00:00, 5.60MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_039/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.12k/3.12k [00:00<00:00, 17.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_042/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.95M/1.95M [00:00<00:00, 3.26MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hoferlab/SWC_042/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.12k/3.12k [00:00<00:00, 16.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_043/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.35M/4.35M [00:00<00:00, 5.94MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hoferlab/SWC_043/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.24k/3.24k [00:00<00:00, 18.0kB/s]
# 100/156
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_052/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.11M/4.11M [00:00<00:00, 5.84MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_052/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 16.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_053/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.81M/4.81M [00:00<00:00, 6.73MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_053/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 16.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_054/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.85M/2.85M [00:00<00:00, 4.17MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_054/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_058/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.67M/2.67M [00:00<00:00, 3.86MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mrsicflogellab/SWC_058/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.07k/3.07k [00:00<00:00, 18.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_060/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.28M/1.28M [00:00<00:00, 2.23MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_060/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.08k/3.08k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/hoferlab/SWC_061/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.58M/1.58M [00:00<00:00, 2.62MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_061/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_065/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.56M/2.56M [00:00<00:00, 3.75MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mrsicflogellab/SWC_065/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.07k/3.07k [00:00<00:00, 16.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_066/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.54M/1.54M [00:00<00:00, 2.70MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/hoferlab/SWC_066/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.08k/3.08k [00:00<00:00, 16.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA005/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.06M/5.06M [00:00<00:00, 6.42MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA005/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA006/_ibl_subjectTrials.table.pqt: 100%|██████████| 9.88M/9.88M [00:01<00:00, 6.55MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA006/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA011/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.14M/4.14M [00:00<00:00, 4.83MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA011/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 19.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA012/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.57M/3.57M [00:00<00:00, 4.84MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA012/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA014/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.44M/3.44M [00:00<00:00, 5.07MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA014/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.24k/3.24k [00:00<00:00, 16.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA015/_ibl_subjectTrials.table.pqt: 100%|██████████| 13.0M/13.0M [00:03<00:00, 4.06MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA015/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 12.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA017/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.44M/5.44M [00:03<00:00, 1.66MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA017/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA030/_ibl_subjectTrials.table.pqt: 100%|██████████| 6.99M/6.99M [00:00<00:00, 8.03MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA030/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 13.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA033/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.42M/4.42M [00:03<00:00, 1.41MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA033/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA034/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.19M/2.19M [00:00<00:00, 3.23MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA034/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA035/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.22M/3.22M [00:00<00:00, 4.61MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA035/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.21k/3.21k [00:00<00:00, 18.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA036/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.23M/4.23M [00:00<00:00, 5.72MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA036/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA037/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.46M/2.46M [00:00<00:00, 3.48MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA037/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 19.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA044/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.33M/4.33M [00:00<00:00, 5.54MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA044/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA048/_ibl_subjectTrials.table.pqt: 100%|██████████| 6.78M/6.78M [00:00<00:00, 7.89MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA048/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 12.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA049/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.39M/4.39M [00:00<00:00, 5.67MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA049/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/churchlandlab_ucla/UCLA052/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.50M/3.50M [00:00<00:00, 5.12MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/churchlandlab_ucla/UCLA052/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-01576/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.30M/3.30M [00:00<00:00, 4.37MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01576/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.21k/3.21k [00:00<00:00, 16.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-01577/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.04M/2.04M [00:01<00:00, 1.25MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-01577/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01592/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.43M/1.43M [00:00<00:00, 2.30MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01592/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 17.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01935/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.66M/2.66M [00:00<00:00, 3.80MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01935/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01936/_ibl_subjectTrials.table.pqt: 100%|██████████| 1.98M/1.98M [00:00<00:00, 3.25MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-01936/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.14k/3.14k [00:00<00:00, 12.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-01937/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.83M/4.83M [00:00<00:00, 6.30MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-01937/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.26k/3.26k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02368/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.96M/2.96M [00:00<00:00, 3.61MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-02368/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 16.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02369/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.90M/2.90M [00:00<00:00, 3.33MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-02369/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02370/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.37M/2.37M [00:00<00:00, 3.45MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02370/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-02372/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.65M/3.65M [00:00<00:00, 4.82MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02372/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02373/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.86M/3.86M [00:00<00:00, 5.24MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-02373/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 18.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZFM-04308/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.02M/4.02M [00:00<00:00, 5.34MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-04308/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.21k/3.21k [00:00<00:00, 16.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-05236/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.03M/4.03M [00:02<00:00, 1.69MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZFM-05236/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 17.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_1897/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.70M/2.70M [00:00<00:00, 3.42MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZM_1897/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.24k/3.24k [00:00<00:00, 17.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZM_1898/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.39M/4.39M [00:00<00:00, 6.16MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_1898/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_2240/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.50M/2.50M [00:00<00:00, 3.83MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZM_2240/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 15.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZM_2241/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.39M/3.39M [00:00<00:00, 4.63MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_2241/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_2245/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.65M/2.65M [00:00<00:00, 3.81MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_2245/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/mainenlab/ZM_3003/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.38M/2.38M [00:00<00:00, 3.94MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/mainenlab/ZM_3003/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.18k/3.18k [00:00<00:00, 16.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_13/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.45M/5.45M [00:00<00:00, 6.59MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_13/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_14/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.91M/3.91M [00:01<00:00, 2.23MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_14/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 17.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_16/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.37M/3.37M [00:00<00:00, 5.14MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_16/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.13k/3.13k [00:00<00:00, 14.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_17/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.54M/2.54M [00:00<00:00, 3.82MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_17/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 14.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_18/_ibl_subjectTrials.table.pqt: 100%|██████████| 4.14M/4.14M [00:00<00:00, 5.56MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_18/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 17.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_19/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.46M/2.46M [00:02<00:00, 1.01MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_19/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 14.8kB/s]
# 150/156
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_20/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.69M/3.69M [00:00<00:00, 5.32MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_20/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_25/_ibl_subjectTrials.table.pqt: 100%|██████████| 2.67M/2.67M [00:00<00:00, 3.65MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_25/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_26/_ibl_subjectTrials.table.pqt: 100%|██████████| 5.75M/5.75M [00:00<00:00, 7.64MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_26/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_27/_ibl_subjectTrials.table.pqt: 100%|██████████| 3.86M/3.86M [00:02<00:00, 1.69MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_27/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.19k/3.19k [00:00<00:00, 14.7kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/aggregates/Subjects/wittenlab/ibl_witten_29/_ibl_subjectTrials.table.pqt: 100%|██████████| 8.18M/8.18M [00:00<00:00, 10.3MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_29/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 17.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_32/_ibl_subjectTrials.table.pqt: 100%|██████████| 9.11M/9.11M [00:01<00:00, 5.09MB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/public/aggregates/Subjects/wittenlab/ibl_witten_32/_ibl_subjectTraining.table.pqt: 100%|██████████| 3.25k/3.25k [00:00<00:00, 18.3kB/s]

# %% [markdown]
# Once we have this large training table aggregated across all subjects we can manipulate this table to view different properties. For example we can see how the pyshcometric curves varies across the different training stages across all subjects

# %%
import seaborn as sns
# plot psychometric curves for the whole dataframe
all_trials = all_trials.reset_index()
all_trials['signed_contrast'] = np.NaN
all_trials.loc[i := np.isnan(all_trials['contrastRight']), 'signed_contrast'] = all_trials.loc[i, 'contrastLeft']
all_trials.loc[~i, 'signed_contrast'] = - all_trials.loc[~i, 'contrastRight']

fig, ax = plt.subplots(1, 1, sharex=True, figsize=(16, 8))
sns.lineplot(data=all_trials.loc[all_trials['probabilityLeft'] == 0.5], x='signed_contrast', y='choice', hue='training_status', ax=ax)
# Out:
# <Axes: xlabel='signed_contrast', ylabel='choice'>

# %% [markdown]
# Or we can look how the performance on easy trial progresses over training days across labs

# %%
# Remove duplicate rows that we don't need for the plots
fig = sns.FacetGrid(all_trials.drop_duplicates('session'),
                    col="lab", col_wrap=4,
                    sharex=True, sharey=True, aspect=1, hue="subject", xlim=[-1, 90])
fig.map(sns.lineplot, "training_day",
        "performance_easy", color='gray', alpha=0.3)

# %% [markdown]
# # Additional resources
#
# Documentation
#
# - [ONE documentation](https://int-brain-lab.github.io/iblenv/notebooks_external/one_quickstart.html#)
# - [Getting started with ONE](https://colab.research.google.com/drive/1y3sRI1wC7qbWqN6skvulzPOp6xw8tLm7)
# - [Loading trials data](https://int-brain-lab.github.io/iblenv/notebooks_external/loading_trials_data.html)

# %% [markdown]
# Where can I find help?
# - Issues with the data? Post an issue here: https://neurostars.org/ with the tag `ibl`
# - Alternatively post an issue here: https://github.com/int-brain-lab/iblenv/issues
# - General questions about the datasets or publications? Email: info@internationalbrainlab.org
